# %% [markdown]
# ## Lab 2: Data Versioning with DVC and API Ingestion
# -   **Course:** Engineering of Intelligent Models (MLOps & LLMOps)
# -   **Module:** M1 – MLOps Foundations
# -   **Focus Tool:** DVC & Open-Meteo API
# -   **Format:** Hands-on Laboratory
# -   **Branch:** `Lab2`
#
# ### 1\. Goal of the Lab
# The objective of this lab is to move away from static, manual CSV management and implement an engineering approach to the data lifecycle. In Machine Learning, your "source" is not just code: it is the combination of code and the exact state of the data at the time of training. You will learn how to:
#
# 1. **Initialise DVC** to track entire directories, including datasets and model weights.
# 2. **Implement professional ingestion** using the Open-Meteo API with unique timestamps for every run.
# 3. **Understand the Metafile (.dvc)** and how it creates a "bridge" between Git's small text tracking and DVC's large binary storage.
# 4. **Integrate DVC hashes into MLflow** to ensure absolute traceability across your pipeline.

# %% [markdown]
# ### 2\. Version Control: Switching Branches
# Before proceeding, ensure your workspace is clean. It is a best practice to keep each lab's progress on a separate branch for easy comparison.
#
# Switch from `Lab1` to a new branch for this session.

# %%
# Create and switch to the Lab2 branch
# !git checkout -b Lab2
# Out:
# fatal: a branch named 'Lab2' already exists

# %% [markdown]
# ### 3\. Initialising DVC for Directory Tracking
# DVC is not just a storage tool; it is a reproducibility framework. While Git tracks your source code, DVC will track the contents of your `data/` and `models/` folders. Crucially, **DVC can track any large file**, including model weights (e.g., `.pkl`, `.h5`, `.onnx`), preventing your Git repository from becoming bloated.
#
# Initialise DVC and configure a local remote (this simulates an external cloud bucket like S3). You can check DVC documentation for more details on setting up different types of remotes (e.g., S3, GCS, Azure) in here [https://doc.dvc.org/user-guide/data-management/remote-storage](https://doc.dvc.org/user-guide/data-management/remote-storage).
#
# > **Note**: Do not forget to add DVC to your `requirements.txt` and install it in your environment if you haven't already.

# %%
# For me, I need to change the current working directory to the project root ('EMI-WeatherForecast') to run DVC commands.
import os
os.chdir('../../')  # Change to project root if notebook is in a subfolder

# %%
# Initialise DVC in the project root
# !dvc init

# Setup a local directory as a 'remote' storage to simulate an external bucket
# If you're on Windows, use backslashes. On Unix-based systems, use forward slashes: mkdir -p tmp/dvc_remote
# !mkdir tmp\dvc_remote
# !dvc remote add -d local_storage tmp/dvc_remote

# Commit DVC internal configuration to Git
# !git add .dvc .dvcignore
# !git commit -m "Initialize DVC with local remote storage"
# Out:
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/treeverse/dvc>
# Setting 'local_storage' as a default remote.
# [Lab2 ce1e383] Initialize DVC with local remote storage
#  3 files changed, 10 insertions(+)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore

# %% [markdown]
# ##### What is a DVC "Remote"?
# In your project, Git only knows about the tiny `.dvc` pointer files (metadata). It has no idea where the actual multi-gigabyte CSV files are (and also, Git cannot handle large files).
#
# By setting up a remote:
# -   **Git** tracks the "recipe" (the `.dvc` file).
# -   **DVC Remote** tracks the "ingredients" (the actual data blobs). Without a remote, if you deleted your local `data/` folder and your local DVC cache, your data would be gone forever, even if you had the Git commits.
#
# In a production environment, you would never store datasets on your local hard drive alone. You would use **Amazon S3, Google Cloud Storage, or Azure Blob Storage**.
# -   The folder `/tmp/dvc_remote` acts as a **local mock** of these cloud services.
# -   It allows you to practice the `dvc push` and `dvc pull` commands, which are the primary way team members sync data without passing around massive files via email or USB.
#
# If a colleague clones my `EMI-WeatherForecast` repo, they will get your code and the `.dvc` files, but the `data/` folder will be empty.
# -   Because I configured a remote and, If I ran `dvc push`, your colleague can simply run `dvc pull`.
# -   DVC will look at the hash in the `.dvc` file, go to the remote folder, and download the exact version of the weather data needed for that specific Git branch.

# %% [markdown]
# ### 4\. Dynamic Data Ingestion with Timestamps
# In production systems, data arrives continuously. Overwriting a single `weather.csv` file is dangerous because it destroys historical context. We will save data with **ISO-8601 timestamps**, allowing DVC to track the arrival of new files automatically.
#
# Update your `requirements.txt` and make sure you `pip install` them before running the ingestion script.
#
# ```bash
# mlflow==3.10.0
# pandas==2.3.3
# dvc==3.66.1
# openmeteo-requests==1.7.5
# requests-cache==1.3.0
# retry-requests==2.0.0
# pyyaml==6.0.3
# ```

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: mlflow==3.10.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: pandas==2.3.3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: dvc==3.66.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 3)) (3.66.1)
# Requirement already satisfied: openmeteo-requests==1.7.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 4)) (1.7.5)
# Requirement already satisfied: requests-cache==1.3.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: retry-requests==2.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: pyyaml==6.0.3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from -r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: mlflow-skinny==3.10.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: mlflow-tracing==3.10.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: Flask-CORS<7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: Flask<4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (1.18.4)
# Requirement already satisfied: cryptography<47,>=43.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (46.0.5)
# Requirement already satisfied: docker<8,>=4.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: graphene<4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: matplotlib<4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (3.10.8)
# Requirement already satisfied: numpy<3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (2.4.2)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (23.0.1)
# Requirement already satisfied: scikit-learn<2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: scipy<2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: skops<1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (2.0.47)
# Requirement already satisfied: waitress<4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow==3.10.0->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from pandas==2.3.3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from pandas==2.3.3->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from pandas==2.3.3->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (25.4.0)
# Requirement already satisfied: celery in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (5.6.2)
# Requirement already satisfied: colorama>=0.3.9 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (5.0.9)
# Requirement already satisfied: distro>=1.3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: dulwich in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: dvc-data<3.19.0,>=3.18.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (3.18.3)
# Requirement already satisfied: dvc-http>=2.29.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2.32.0)
# Requirement already satisfied: dvc-objects in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (5.2.0)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.40.2)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: flufl.lock<10,>=8.1.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: fsspec>=2024.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2026.2.0)
# Requirement already satisfied: funcy>=1.14 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: hydra-core>=1.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.0.10)
# Requirement already satisfied: kombu in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (5.6.2)
# Requirement already satisfied: networkx>=2.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: omegaconf in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: packaging>=19 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pathspec<1,>=0.10.3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (4.9.2)
# Requirement already satisfied: psutil>=5.8 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (7.2.2)
# Requirement already satisfied: pydot>=1.2.4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: requests>=2.22 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: rich>=12 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (14.3.3)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: shortuuid>=0.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: tabulate>=0.8.7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: tqdm<5,>=4.63.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (4.67.3)
# Requirement already satisfied: voluptuous>=0.11.7 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc==3.66.1->-r requirements.txt (line 3)) (4.0)
# Requirement already satisfied: niquests>=3.15.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (3.17.0)
# Requirement already satisfied: openmeteo-sdk>=1.22.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (1.25.0)
# Requirement already satisfied: cattrs>=22.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from requests-cache==1.3.0->-r requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: url-normalize>=2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from requests-cache==1.3.0->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: urllib3>=1.25.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from requests-cache==1.3.0->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: cachetools<8,>=5.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (7.0.1)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.92.0)
# Requirement already satisfied: fastapi<1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.133.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: uvicorn<1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.41.0)
# Requirement already satisfied: Mako in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from alembic!=1.10.0,<2->mlflow==3.10.0->-r requirements.txt (line 1)) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from cryptography<47,>=43.0.0->mlflow==3.10.0->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (2.48.0)
# Requirement already satisfied: pywin32>=304 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from docker<8,>=4.0.0->mlflow==3.10.0->-r requirements.txt (line 1)) (311)
# Requirement already satisfied: dictdiffer>=0.8.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc==3.66.1->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc==3.66.1->-r requirements.txt (line 3)) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc==3.66.1->-r requirements.txt (line 3)) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc==3.66.1->-r requirements.txt (line 3)) (3.11.7)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from celery->dvc==3.66.1->-r requirements.txt (line 3)) (4.2.4)
# Requirement already satisfied: vine<6.0,>=5.1.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from celery->dvc==3.66.1->-r requirements.txt (line 3)) (5.1.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from celery->dvc==3.66.1->-r requirements.txt (line 3)) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from celery->dvc==3.66.1->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from celery->dvc==3.66.1->-r requirements.txt (line 3)) (1.1.1.2)
# Requirement already satisfied: tzlocal in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from celery->dvc==3.66.1->-r requirements.txt (line 3)) (5.3.1)
# Requirement already satisfied: starlette>=0.40.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from fastapi<1->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from fastapi<1->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from fastapi<1->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from Flask<4->mlflow==3.10.0->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from Flask<4->mlflow==3.10.0->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from Flask<4->mlflow==3.10.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from Flask<4->mlflow==3.10.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from Flask<4->mlflow==3.10.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: six<2.0,>=1.12 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from flatten-dict<1,>=0.4.1->dvc==3.66.1->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: atpublic in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from flufl.lock<10,>=8.1.0->dvc==3.66.1->-r requirements.txt (line 3)) (7.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from graphene<4->mlflow==3.10.0->-r requirements.txt (line 1)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from graphene<4->mlflow==3.10.0->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: entrypoints in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from gto<2,>=1.6.0->dvc==3.66.1->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: pydantic-settings>=2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from gto<2,>=1.6.0->dvc==3.66.1->-r requirements.txt (line 3)) (2.13.1)
# Requirement already satisfied: semver>=2.13.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from gto<2,>=1.6.0->dvc==3.66.1->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from gto<2,>=1.6.0->dvc==3.66.1->-r requirements.txt (line 3)) (0.24.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from kombu->dvc==3.66.1->-r requirements.txt (line 3)) (5.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from matplotlib<4->mlflow==3.10.0->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from matplotlib<4->mlflow==3.10.0->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from matplotlib<4->mlflow==3.10.0->-r requirements.txt (line 1)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from matplotlib<4->mlflow==3.10.0->-r requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from matplotlib<4->mlflow==3.10.0->-r requirements.txt (line 1)) (12.1.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from requests>=2.22->dvc==3.66.1->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from requests>=2.22->dvc==3.66.1->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from requests>=2.22->dvc==3.66.1->-r requirements.txt (line 3)) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from scikit-learn<2->mlflow==3.10.0->-r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from scikit-learn<2->mlflow==3.10.0->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: pygit2>=1.14.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (1.19.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (2.22.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (2.9.1)
# Requirement already satisfied: prettytable>=3.9 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from skops<1->mlflow==3.10.0->-r requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.10.0->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: h11>=0.8 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from uvicorn<1->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: aiohttp in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (3.13.3)
# Requirement already satisfied: pycparser in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow==3.10.0->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from click-repl>=0.2.0->celery->dvc==3.66.1->-r requirements.txt (line 3)) (3.0.52)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from hydra-core>=1.1->dvc==3.66.1->-r requirements.txt (line 3)) (4.9.3)
# Requirement already satisfied: appdirs in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from iterative-telemetry>=0.0.7->dvc==3.66.1->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: filelock in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from iterative-telemetry>=0.0.7->dvc==3.66.1->-r requirements.txt (line 3)) (3.25.0)
# Requirement already satisfied: urllib3-future<3,>=2.13.903 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from niquests>=3.15.2->openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (2.16.900)
# Requirement already satisfied: wassima<3,>=1.0.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from niquests>=3.15.2->openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: jh2<6.0.0,>=5.0.3 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (5.0.10)
# Requirement already satisfied: qh3<2.0.0,>=1.5.4 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: flatbuffers==25.9.23 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from openmeteo-sdk>=1.22.0->openmeteo-requests==1.7.5->-r requirements.txt (line 4)) (25.9.23)
# Requirement already satisfied: wcwidth in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from prettytable>=3.9->skops<1->mlflow==3.10.0->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from rich>=12->dvc==3.66.1->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from rich>=12->dvc==3.66.1->-r requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc==3.66.1->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from starlette>=0.40.0->fastapi<1->mlflow-skinny==3.10.0->mlflow==3.10.0->-r requirements.txt (line 1)) (4.12.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc==3.66.1->-r requirements.txt (line 3)) (1.5.4)
# Requirement already satisfied: setuptools in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from zc.lockfile>=1.2.1->dvc==3.66.1->-r requirements.txt (line 3)) (80.10.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\tomfp\anaconda3\envs\lab1\Lib\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc==3.66.1->-r requirements.txt (line 3)) (1.23.0)

# %% [markdown]
# Create `src/ingestion/get_data.py` and paste the following logic:
#
# > **NOTE**: This script retrieves hourly weather data (`temperature_2m`, `relative_humidity_2m`, `precipitation`) for a specific location (I chose Sintra 😅) and time range, processes it into a DataFrame, and saves it as a CSV file with a unique timestamp in the filename. The use of `requests_cache` and `retry` ensures that API calls are efficient and resilient to transient failures.
#
# ```python
# import openmeteo_requests
# import pandas as pd
# import requests_cache
# from retry_requests import retry
# from datetime import datetime
# import os
#
#
# def fetch_weather_data():
#     # Setup API client with cache to avoid redundant calls
#     cache_session = requests_cache.CachedSession('.cache', expire_after=-1)
#     retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
#     openmeteo = openmeteo_requests.Client(session=retry_session)
#
#     # API Parameters for the Weather Forecast Project
#     url = "https://archive-api.open-meteo.com/v1/archive"
#     params = {
#         "latitude": 38.801,  # Sintra, Portugal
#         "longitude": -9.3783,
#         "start_date": "2026-02-06",
#         "end_date": "2026-02-20",
#         "hourly": ["temperature_2m", "relative_humidity_2m", "precipitation"],
#         "timezone": "auto",
#     }
#
#     print(f"Requesting weather data from Open-Meteo...")
#     responses = openmeteo.weather_api(url, params=params)
#     response = responses[0]  # Assuming we only have one response for the given parameters
#
#     # Process hourly data into a dictionary
#     hourly = response.Hourly()
#     hourly_data = {
#         "date": pd.date_range(
#             start=pd.to_datetime(hourly.Time() + response.UtcOffsetSeconds(), unit="s", utc=True),
#             end=pd.to_datetime(hourly.TimeEnd() + response.UtcOffsetSeconds(), unit="s", utc=True),
#             freq=pd.Timedelta(seconds=hourly.Interval()),
#             inclusive="left"
#         ),
#         "temperature_2m": hourly.Variables(0).ValuesAsNumpy(),
#         "relative_humidity_2m": hourly.Variables(1).ValuesAsNumpy(),
#         "precipitation": hourly.Variables(2).ValuesAsNumpy()
#     }
#
#     df = pd.DataFrame(data=hourly_data)
#
#     # Generate timestamped filename for automatic capturing
#     timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#     filename = f"weather_{timestamp}.csv"
#     os.makedirs("data/raw", exist_ok=True)
#     output_path = os.path.join("data/raw", filename)
#
#     df.to_csv(output_path, index=False)
#     print(f"Data ingested and saved to: {output_path}")
#
#
# if __name__ == "__main__":
#     fetch_weather_data()
# ```

# %% [markdown]
# ### 5\. Tracking the Entire Data Folder
# Instead of tracking individual files, we will tell DVC to track the `data/raw` folder as a single entity. When new timestamped files arrive, running `dvc add data/raw` will update the folder's unique hash.
#
# Execute the ingestion and hand over control to DVC.

# %%
# First we need to remove 'data/raw' from Git tracking if it was added in Lab1
# !git rm -r --cached data/raw
# !git commit -m "Stop tracking data/raw"
# Out:
# rm 'data/raw/weather.csv'
# [Lab2 7628a03] Stop tracking data/raw
#  1 file changed, 5 deletions(-)
#  delete mode 100644 data/raw/weather.csv

# %%
# 1. RUN ingestion
# !python src/ingestion/get_data.py
# Out:
# Requesting weather data from Open-Meteo...
# Data ingested and saved to: data/raw\weather_20260302_164457.csv

# %%
# 2. ADD the whole folder to DVC (calculates hash)
# !dvc add data/raw
# Out:
# To track the changes with git, run:
#
# 	git add 'data\raw.dvc' 'data\.gitignore'
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph

# %%
# 3. COMMIT the metadata to Git
# !git add data/raw.dvc
# !git commit -m "Track raw data folder with DVC"
# Out:
# [Lab2 d15d3fa] Track raw data folder with DVC
#  1 file changed, 6 insertions(+)
#  create mode 100644 data/raw.dvc

# %%
# 4. PUSH the actual data to your Remote (/tmp/dvc_remote)
# !dvc push
# Out:
# 3 files pushed

# %% [markdown]
# ##### Git vs DVC: CLI commands analogy
#
# | Command | Action | Analogous to |
# | --- | --- | --- |
# | **`dvc add`** | Moves data to local cache and creates `.dvc` pointer. | `git add` |
# | **`dvc push`** | Uploads data from local cache to Remote Storage. | `git push` |
# | **`dvc pull`** | Downloads data from Remote Storage to local workspace. | `git pull` |

# %% [markdown]
# ### 6\. Updating MLflow: Tracking Data Lineage
# We will now update our connectivity test to capture the **DVC Hash** of the data folder. This creates a permanent link between your experiment and the exact state of your data. If you ever need to reproduce this exact run, you can use the hash to revert your data folder to this specific state.
#
# Create `src/training/lab2_dvc_integration.py`:
#
# ```python
# import mlflow
# import pandas as pd
# import dvc.api
# import yaml
# import os
#
# mlflow.set_tracking_uri("http://localhost:5000")
# mlflow.set_experiment("Lab2_DVC_Integration")
#
#
# def dvc_integration():
#     # Use the DVC API to get the internal URL/Hash of the tracked folder
#     try:
#         # get_url returns the path in the .dvc/cache (which is named by the MD5 hash)
#         resource_url = dvc.api.get_url(path='data/raw', repo='.')
#         folder_hash = os.path.basename(resource_url)
#
#     except Exception as e:
#         print(f"Error accessing DVC API: {e}")
#         return
#
#     with mlflow.start_run(run_name="Lab2_DVC_Versioning") as run:
#         # Select the latest file for the current run
#         files = [f for f in os.listdir("data/raw") if f.endswith(".csv")]
#         latest_file = sorted(files)[-1]
#         df = pd.read_csv(os.path.join("data/raw", latest_file))
#
#         # Log the DVC Hash for Data Lineage
#         # This provides a 1:1 link between this MLflow run and the DVC data state
#         mlflow.log_param("dvc_data_hash", folder_hash)
#         mlflow.log_param("input_file", latest_file)
#         mlflow.log_metric("row_count", len(df))
#         mlflow.log_metric("average_temperature", df["temperature_2m"].mean())
#         mlflow.log_metric("average_relative_humidity", df["relative_humidity_2m"].mean())
#         mlflow.log_metric("average_precipitation", df["precipitation"].mean())
#
#         print(f"Logged successfully!")
#         print(f"DVC Data Hash extracted via API: {folder_hash}")
#
#
# if __name__ == "__main__":
#     dvc_integration()
# ```

# %% [markdown]
# > **NOTE**: The use of `dvc.api.read` allows us to programmatically access the metadata of our tracked folder. By logging the `md5` hash to MLflow, we create a direct link between our experiment and the exact version of the data used. This is crucial for reproducibility, as it allows us to revert anytime to the specific state of the data that was used for that run, even if new files have been added since then.

# %% [markdown]
# Run the script to see the integration in action:

# %%
# !python src/training/lab2_dvc_integration.py
# Out:
# Logged successfully!
# DVC Data Hash extracted via API: 1fac02ac7eca15e3b6bac6d6694e2d.dir
# 🏃 View run Lab2_DVC_Versioning at: http://localhost:5000/#/experiments/2/runs/b4c71aed1abf422dbc79c6d917f279ad
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 2026/03/02 16:46:06 INFO mlflow.tracking.fluent: Experiment with name 'Lab2_DVC_Integration' does not exist. Creating a new experiment.

# %% [markdown]
# ### 7\. Lab Checklist
# 1.  Inspect `/tmp/dvc_remote`. Do you see hashed folders representing your data?
# 2.  Does the `lab2_dvc_integration.py` correctly extract the `md5` using `dvc.api.read`?
# 3.  In the MLflow UI, can you verify if dataset versioning is working? It should be available as a parameter in the run details (`dvc_data_hash`).
# 	- This hash is your "data fingerprint" for that specific run. If you ever need to reproduce this run, you can use this hash to revert your `data/raw` folder to the exact state it was in at the time of training, ensuring perfect reproducibility even as new data arrives.

# %% [markdown]
# ### 8\. Next Steps
# Your data is versioned, shared on a remote, and programmatically linked to your experiments. In the next lab, we will integrate Hydra and remove the hardcoded API coordinates and date ranges. This will allow us to run the same ingestion logic for any location and time period, making our pipeline truly dynamic and reusable.
